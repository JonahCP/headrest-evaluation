# %%
import mne 
# %matplotlib tk

# Load data
# Make sure you use numpy version 1.23.5
raw_data_1 = mne.io.read_raw_gdf('data/11_17_23_364DEEGtests/JasonSSVEP1.gdf', eog=['sens13', 'sens14', 'sens15'], preload=True, stim_channel='Status', verbose='INFO')
raw_data_2 = mne.io.read_raw_gdf('data/11_17_23_364DEEGtests/JasonSSVEP2.gdf', eog=['sens13', 'sens14', 'sens15'], preload=True, stim_channel='Status', verbose='INFO')
raw_data_3 = mne.io.read_raw_gdf('data/11_17_23_364DEEGtests/JasonSSVEP3.gdf', eog=['sens13', 'sens14', 'sens15'], preload=True, stim_channel='Status', verbose='INFO')
raw_data_4 = mne.io.read_raw_gdf('data/11_17_23_364DEEGtests/JasonSSVEP4.gdf', eog=['sens13', 'sens14', 'sens15'], preload=True, stim_channel='Status', verbose='INFO')
# Out:
# Extracting EDF parameters from c:\Users\jcpro\OneDrive\Documents\Code\SeniorDesign\headrest-evaluation\analysis\data\11_17_23_364DEEGtests\JasonSSVEP1.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# FP1, FPZ, FP2, F7, F3, FZ, F4, F8, FC5, FC1, FC2, FC6, M1, T7, C3, CZ, C4, T8, M2, CP5, CP1, CP2, CP6, P7, P3, PZ, P4, P8, POZ, O1, OZ, O2
# Creating raw.info structure...
# Reading 0 ... 26111  =      0.000 ...    50.998 secs...
# Extracting EDF parameters from c:\Users\jcpro\OneDrive\Documents\Code\SeniorDesign\headrest-evaluation\analysis\data\11_17_23_364DEEGtests\JasonSSVEP2.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# FP1, FPZ, FP2, F7, F3, FZ, F4, F8, FC5, FC1, FC2, FC6, M1, T7, C3, CZ, C4, T8, M2, CP5, CP1, CP2, CP6, P7, P3, PZ, P4, P8, POZ, O1, OZ, O2
# ...

# %%
raw_data_1.info
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: FP1, FPZ, FP2, F7, F3, FZ, F4, F8, FC5, FC1, FC2, FC6, M1, T7, ...
#  chs: 32 EEG, 3 EOG, 1 Stimulus
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 256.0 Hz
#  meas_date: 2023-11-17 17:48:04 UTC
#  nchan: 36
#  projs: []
#  sfreq: 512.0 Hz
#  subject_info: 4 items (dict)
# >

# %%
raw_data_1.plot(scalings='auto')
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
raw_data_1.describe()
# Out:
# <RawGDF | JasonSSVEP1.gdf, 36 x 26112 (51.0 s), ~7.2 MB, data loaded>
# ch  name    type  unit        min         Q1     median         Q3        max
#  0  FP1     EEG   µV    -8941919921.88  -8890679687.50  -8868240234.38  -8826240234.38       0.00
#  1  FPZ     EEG   µV    -10672439453.12  -10632839843.75  -10592400390.62  -10559639648.44       0.00
#  2  FP2     EEG   µV         0.00  4249919921.88  4262160156.25  4291320312.50  4447800292.97
#  3  F7      EEG   µV    -3815880126.95  -3744239990.23  -3721439941.41  -3703289855.96       0.00
#  4  F3      EEG   µV    -7374120117.19  -7319520019.53  -7298279785.16  -7281720214.84       0.00
#  5  FZ      EEG   µV         0.00  2574600097.66  2589719970.70  2602319824.22  2637000000.00
#  6  F4      EEG   µV         0.00  11295240234.38  11302559570.31  11313120117.19  11362080078.12
#  7  F8      EEG   µV         0.00  743880004.88  761880004.88  781320007.32  880200012.21
# ...

# %%
print(len(raw_data_1.annotations))
print(set(raw_data_1.annotations.duration))
print(set(raw_data_1.annotations.description))
print(raw_data_1.annotations.onset)
# Out:
# 10
# {0.001953125}
# {'103', '99', '100', '102', '101', '199'}
# [15.505859 17.503906 21.509766 23.509766 27.539062 29.539062 33.546875
#  35.544922 39.570312 41.570312]

# %%
filtered_data_1 = raw_data_1.copy().filter(l_freq=1, h_freq=30, verbose='INFO')
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 1691 samples (3.303 s)

# %%
filtered_data_1.plot(scalings='auto')
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Channels marked as bad:
# none

# %%
filtered_data_1.info
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: FP1, FPZ, FP2, F7, F3, FZ, F4, F8, FC5, FC1, FC2, FC6, M1, T7, ...
#  chs: 32 EEG, 3 EOG, 1 Stimulus
#  custom_ref_applied: False
#  highpass: 1.0 Hz
#  lowpass: 30.0 Hz
#  meas_date: 2023-11-17 17:48:04 UTC
#  nchan: 36
#  projs: []
#  sfreq: 512.0 Hz
#  subject_info: 4 items (dict)
# >
